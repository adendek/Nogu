# %% [markdown]
# # Analysis Notebook Template
#
# This notebook template is designed to expedite future development and serve as a starting point for various types of analysis, including:
# - Exploratory Data Analysis (EDA)
# - Model Training
# - Running Simulations
# - Result Evaluation
#
# Below is a roadmap for the study:
#
# 1. Objective 1
# 2. Objective 2
# 3. Objective 3
#
# Please replace the above objectives with your specific goals for this analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
def get_data() -> pd.DataFrame:
    """Returns data needed for analysis."""
    return pd.DataFrame({"A":[1,2,3],
                         "B":[2,3,4]})

# %%
df = get_data()

plt.scatter(df["A"], df["B"])
plt.xlabel("A")
plt.ylabel("B");
